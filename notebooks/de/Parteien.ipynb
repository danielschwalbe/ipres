# %% [markdown]
# # Parteienkonfiguration

# %% [markdown]
# ## Parteien einlesen oder erzeugen

# %%
from ipres.parties import Parties
parties_config = Parties()
parties_config.setup()

# %%
parties_config.save("data/examples/parties_save_test.csv")
