# %% [markdown]
# # Wahlkreise konfigurieren
# Beispiele zur Benutzung der ConstituenciesConfig Klasse

# %% [markdown]
# ## Wahlkreise zufällig erzeugen oder aus Datei laden

# %%
from ipres.constituencies_config import ConstituenciesConfig

constituencies_config = ConstituenciesConfig()
constituencies_config.setup()

# %% [markdown]
# ## Wahlkreise speichern

# %%
constituencies_config.save()
